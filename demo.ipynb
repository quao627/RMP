# %%
import pandas as pd
pd.options.display.max_columns = 999

# %%
school = pd.read_csv("School/Vanderbilt.csv", index_col=0)
professor = pd.read_csv("Ratings/Daniel_Arena.csv", index_col=0)

# %%
print("")

# %%
school.head()
# Out:
#               tDept  tSid       institution_name     tFname tMiddlename  \
# 0  Computer Science  4002  Vanderbilt University     Waseem         NaN
# 1           Biology  4002  Vanderbilt University    Patrick         NaN
# 2         Languages  4002  Vanderbilt University      Jacob         NaN
# 3         Languages  4002  Vanderbilt University  Trozenski         NaN
# 4       Engineering  4002  Vanderbilt University       Mark         NaN
#
#      tLname      tid  tNumRatings rating_class contentType categoryType  \
# 0     Abbas  2522286           19         good     TEACHER    PROFESSOR
# 1     Abbot   576773           32         good     TEACHER    PROFESSOR
# 2     Abell  2185295            3         good     TEACHER    PROFESSOR
# 3   Abigail  2569568            0         zero     TEACHER    PROFESSOR
# 4  Abkowitz   689793            2         good     TEACHER    PROFESSOR
#
#    overall_rating
# 0             4.6
# 1             4.3
# 2             5.0
# 3             NaN
# ...

# %%
professor.head()
# Out:
#       attendance clarityColor easyColor helpColor  helpCount        id  \
# 0      Mandatory         good      good      good          1  33943011
# 1            NaN         good   average      good          0  33904800
# 2  Not Mandatory         good   average      good          1  33904434
# 3  Not Mandatory         good   average      good          0  33902324
# 4  Not Mandatory         good   average      good          0  33900976
#
#    notHelpCount onlineClass  quality  rClarity  rClass  \
# 0             0         NaN  awesome         5  CS2212
# 1             0      online  awesome         5  CS2212
# 2             0         NaN  awesome         5  CS2212
# 3             0         NaN  awesome         5  CS2212
# 4             0      online  awesome         5  CS2212
#
#                                            rComments       rDate  rEasy  \
# 0  I can't say enough good things about Arena. He...  12/03/2020    4.0
# ...
